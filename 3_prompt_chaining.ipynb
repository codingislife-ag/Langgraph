# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    # fetch title
    title = state['title']
    # call llm generate outline
    prompt = f"Generate a detailed outline for a blog on the topic: {title}"
    outline = model.invoke(prompt).content
    # update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']
    prompt = f"Write a detailed on the title - {title} using the following outline \n {outline}"
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

# add node

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# add edges

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)


workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'I. Introduction\n   A. Explanation of AI\n   B. Brief overview of the rise of AI globally\n   C. Focus on the growth of AI in India\n   \nII. History of AI in India\n   A. Early adoption of AI technologies\n   B. Major milestones in the development of AI in India\n   C. Impact of government policies and initiatives on the growth of AI in India\n\nIII. Current state of AI in India\n   A. Key players in the Indian AI industry\n   B. Growth sectors for AI in India (healthcare, finance, agriculture, etc.)\n   C. Challenges and barriers to AI adoption in India\n\nIV. Impact of AI on Indian society and economy\n   A. Job displacement and creation\n   B. Social implications of AI technology\n   C. Economic benefits and challenges of AI adoption in India\n\nV. Future of AI in India\n   A. Potential applications and advancements in AI technology\n   B. Role of government and private sector in fostering AI innovation\n   C. Predictions for the growth and impact of AI in India in the coming years\n\nVI. Conclusion\n   A. Summary of key points discussed in the blog\n   B. Call to action for readers to stay informed and engage with developments in the AI industry in India\n   C. Final thoughts on the significance of the rise of AI in India', 'content': 'I. Introduction\n\nA. Explanation of AI: Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, typically through the use of algorithms and data. AI encompasses a wide range of technologies such as machine learning, natural language processing, and computer vision.\n\nB. Brief overview of the rise of AI globally: AI has seen significant growth and advancement globally in recent years, with applications in various industries such as healthcare, finance, and transportation.\n\nC. Focus on the growth of AI in India: India has emerged as a key player in the global AI industry, with a rapidly growing ecosystem of startups, research institutions, and multinational companies investing heavily in AI technologies.\n\nII. History of AI in India\n\nA. Early adoption of AI technologies: India has a long history of using AI technologies, with research institutions and educational organizations pioneering the development of AI applications in the country.\n\nB. Major milestones in the development of AI in India: Over the years, India has achieved significant milestones in the AI industry, including the development of AI-driven products and services in sectors such as healthcare, agriculture, and e-commerce.\n\nC. Impact of government policies and initiatives on the growth of AI in India: The Indian government has launched various initiatives to support the growth of AI in the country, including the National AI Strategy and the establishment of AI research centers.\n\nIII. Current state of AI in India\n\nA. Key players in the Indian AI industry: India is home to a growing number of AI startups and research institutions, as well as multinational companies investing in AI research and development in the country.\n\nB. Growth sectors for AI in India: AI is being increasingly used in sectors such as healthcare, finance, agriculture, and education in India, with a focus on developing solutions to address key challenges in these industries.\n\nC. Challenges and barriers to AI adoption in India: Despite the growth of AI in India, there are still challenges such as data privacy concerns, lack of skilled AI professionals, and regulatory issues that need to be addressed for wider adoption of AI technologies.\n\nIV. Impact of AI on Indian society and economy\n\nA. Job displacement and creation: AI has the potential to disrupt traditional job roles in India, leading to job displacement in certain sectors, while also creating new job opportunities in AI-related roles.\n\nB. Social implications of AI technology: AI technologies raise important ethical and social questions regarding privacy, bias, and accountability in India, requir ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#    A. Explanation of AI
#    B. Brief overview of the rise of AI globally
#    C. Focus on the growth of AI in India
#
# II. History of AI in India
#    A. Early adoption of AI technologies
#    B. Major milestones in the development of AI in India
#    C. Impact of government policies and initiatives on the growth of AI in India
#
# III. Current state of AI in India
#    A. Key players in the Indian AI industry
#    B. Growth sectors for AI in India (healthcare, finance, agriculture, etc.)
#    C. Challenges and barriers to AI adoption in India
#
# IV. Impact of AI on Indian society and economy
#    A. Job displacement and creation
#    B. Social implications of AI technology
#    C. Economic benefits and challenges of AI adoption in India
#
# V. Future of AI in India
#    A. Potential applications and advancements in AI technology
#    B. Role of government and private sector in fostering AI innovation
#    C. Predictions for the growth and impact of AI in India in the coming years
#
# VI. Conclusion
#    A. Summary of key points discussed in the blog
#    B. Call to action for readers to stay informed and engage with developments in the AI industry in India
#    C. Final thoughts on the significance of the rise of AI in India

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Explanation of AI: Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, typically through the use of algorithms and data. AI encompasses a wide range of technologies such as machine learning, natural language processing, and computer vision.
#
# B. Brief overview of the rise of AI globally: AI has seen significant growth and advancement globally in recent years, with applications in various industries such as healthcare, finance, and transportation.
#
# C. Focus on the growth of AI in India: India has emerged as a key player in the global AI industry, with a rapidly growing ecosystem of startups, research institutions, and multinational companies investing heavily in AI technologies.
#
# II. History of AI in India
#
# A. Early adoption of AI technologies: India has a long history of using AI technologies, with research institutions and educational organizations pioneering the development of AI applications in the country.
#
# B. Major milestones in the development of AI in India: Over the years, India has achieved significant milestones in the AI industry, including the development of AI-driven products and services in sectors such as healthcare, agriculture, and e-commerce.
#
# C. Impact of government policies and initiatives on the growth of AI in India: The Indian government has launched various initiatives to support the growth of AI in the country, including the National AI Strategy and the establishment of AI research centers.
#
# III. Current state of AI in India
#
# A. Key players in the Indian AI industry: India is home to a growing number of AI startups and research institutions, as well as multinational companies investing in AI research and development in the country.
#
# B. Growth sectors for AI in India: AI is being increasingly used in sectors such as healthcare, finance, agriculture, and education in India, with a focus on developing solutions to address key challenges in these industries.
#
# C. Challenges and barriers to AI adoption in India: Despite the growth of AI in India, there are still challenges such as data privacy concerns, lack of skilled AI professionals, and regulatory issues that need to be addressed for wider adoption of AI technologies.
#
# IV. Impact of AI on Indian society and economy
#
# A. Job displacement and creation: AI has the potential to disrupt traditional job roles in India, leading to job displacement in certain sectors, while also creating new job opportunities in AI-related roles.
#
# B. Social implications of AI technology: AI technologies raise important ethical and social questions regarding privacy, bias, and accountability in India, requiring careful consideration and regulation.
#
# C. Economic benefits and challenges of AI adoption in India: AI has the potential to drive economic growth, improve efficiency, and enhance productivity in India, but there are also challenges such as the digital divide and unequal access to AI technologies that need to be addressed.
#
# V. Future of AI in India
#
# A. Potential applications and advancements in AI technology: The future of AI in India holds great promise, with potential applications in areas such as smart cities, autonomous vehicles, and personalized healthcare.
#
# B. Role of government and private sector in fostering AI innovation: Both the government and the private sector play a crucial role in fostering innovation and research in AI in India, with collaborations between industry and academia being key to driving advancements in AI technology.
#
# C. Predictions for the growth and impact of AI in India in the coming years: The AI industry in India is expected to grow significantly in the coming years, with AI technologies becoming increasingly integrated into various sectors of the economy and society.
#
# VI. Conclusion
#
# A. Summary of key points discussed in the blog: The rise of AI in India represents a significant opportunity for growth and innovation, with the potential to transform various industries and drive economic development in the country.
#
# B. Call to action for readers to stay informed and engage with developments in the AI industry in India: Readers are encouraged to stay informed about the latest developments in the AI industry in India and actively engage in discussions and initiatives to support the growth of AI in the country.
#
# C. Final thoughts on the significance of the rise of AI in India: The rise of AI in India is a transformative force that has the power to drive innovation, create new opportunities, and address key societal challenges, making it a critical area of focus for the future development of the country.
